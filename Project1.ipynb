# %%
import psycopg2

# %%
def create_connection(db_name, db_user, db_password, db_host, db_port):
    connection = None
    try:
        connection = psycopg2.connect(
            database=db_name,
            user=db_user,
            password=db_password,
            host=db_host,
            port=db_port,
        )
        print("Connection to PostgreSQL DB successful")
    except OperationalError as e:
        print(f"The error '{e}' occurred")
    return connection

# %%
db_name = "Project1"
db_user = "postgres"
db_password = "postgres"  
db_host = "localhost"  
db_port = "5432"

# %%
connection = create_connection(db_name, db_user, db_password, db_host, db_port)
# Out:
# Connection to PostgreSQL DB successful

# %%
cursor = connection.cursor()

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
db_server = "dw_2024"

# %%
connection_string = f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"
engine = create_engine(connection_string)

# %%
print(engine)
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/Project1)

# %%
from pathlib import Path
script_path = Path.cwd().parent

# %%
data_path = script_path / "data" / "Project1"
countrycsv = data_path / "list-of-countries_areas-by-continent-2024.csv"

# %%
countrydf = pd.read_csv("./list-of-countries_areas-by-continent-2024.csv", header=None)

# %%
countrydf.columns = ["country", "continent"]

# %%
countrydf
# Out:
#               country      continent
# 0             country         region
# 1               India           Asia
# 2               China           Asia
# 3       United States  North America
# 4           Indonesia           Asia
# ..                ...            ...
# 230        Montserrat  North America
# 231  Falkland Islands  South America
# 232              Niue        Oceania
# 233           Tokelau        Oceania
# 234      Vatican City         Europe
#
# [235 rows x 2 columns]

# %%
cursor.execute("CREATE TABLE olympicHosts (hostID VARCHAR(255) PRIMARY KEY, endDate TIMESTAMP WITH TIME ZONE, startDate TIMESTAMP WITH TIME ZONE, location VARCHAR(255), name VARCHAR(255), season VARCHAR(255), year INT);")

# %%
connection.commit()

# %%
olympic_hosts = pd.read_csv("./olympic_hosts.csv", header=0)

# %%
olympic_hosts['game_end_date'] = pd.to_datetime(olympic_hosts['game_end_date'], format='%Y-%m-%dT%H:%M:%SZ')

# %%
olympic_hosts['game_start_date'] = pd.to_datetime(olympic_hosts['game_start_date'], format='%Y-%m-%dT%H:%M:%SZ')

# %%
olympic_hosts['game_slug'] = olympic_hosts['game_slug'].astype(str)

# %%
olympic_hosts['game_year'] = pd.to_numeric(olympic_hosts['game_year'])

# %%
print(olympic_hosts.dtypes)
# Out:
# game_slug                  object
# game_end_date      datetime64[ns]
# game_start_date    datetime64[ns]
# game_location              object
# game_name                  object
# game_season                object
# game_year                   int64
# dtype: object

# %%
olympic_hosts
# Out:
#                          hostID             endDate           startDate  \
# 0                  beijing-2022 2022-02-20 12:00:00 2022-02-04 15:00:00
# 1                    tokyo-2020 2021-08-08 14:00:00 2021-07-23 11:00:00
# 2              pyeongchang-2018 2018-02-25 08:00:00 2018-02-08 23:00:00
# 3                      rio-2016 2016-08-21 21:00:00 2016-08-05 12:00:00
# 4                    sochi-2014 2014-02-23 16:00:00 2014-02-07 04:00:00
# 5                   london-2012 2012-08-12 19:00:00 2012-07-27 07:00:00
# 6                vancouver-2010 2010-02-28 04:00:00 2010-02-12 16:00:00
# 7                  beijing-2008 2008-08-24 12:00:00 2008-08-08 00:00:00
# 8                    turin-2006 2006-02-26 19:00:00 2006-02-10 07:00:00
# 9                   athens-2004 2004-08-29 18:00:00 2004-08-13 06:00:00
# 10          salt-lake-city-2002 2002-02-24 08:00:00 2002-02-08 15:00:00
# 11                  sydney-2000 2000-10-01 09:00:00 2000-09-15 01:00:00
# 12                  nagano-1998 1998-02-22 11:00:00 1998-02-06 23:00:00
# 13                 atlanta-1996 1996-08-05 21:00:00 1996-07-19 12:00:00
# 14             lillehammer-1994 1994-02-27 19:00:00 1994-02-12 07:00:00
# 15               barcelona-1992 1992-08-09 18:00:00 1992-07-25 06:00:00
# 16             albertville-1992 1992-02-23 19:00:00 1992-02-08 07:00:00
# 17                   seoul-1988 1988-10-02 10:00:00 1988-09-16 22:00:00
# 18                 calgary-1988 1988-02-28 03:00:00 1988-02-13 15:00:00
# 19             los-angeles-1984 1984-08-12 19:00:00 1984-07-28 15:00:00
# 20                sarajevo-1984 1984-02-19 19:00:00 1984-02-08 07:00:00
# 21                  moscow-1980 1980-08-03 18:00:00 1980-07-19 05:00:00
# 22             lake-placid-1980 1980-02-24 01:00:00 1980-02-13 13:00:00
# 23                montreal-1976 1976-07-31 22:00:00 1976-07-17 12:00:00
# 24               innsbruck-1976 1976-02-15 19:00:00 1976-02-04 07:00:00
# 25                  munich-1972 1972-09-11 19:00:00 1972-08-26 07:00:00
# 26                 sapporo-1972 1972-02-13 11:00:00 1972-02-02 23:00:00
# 27             mexico-city-1968 1968-10-28 04:00:00 1968-10-12 16:00:00
# 28                grenoble-1968 1968-02-18 19:00:00 1968-02-06 07:00:00
# 29                   tokyo-1964 1964-10-24 11:00:00 1964-10-09 23:00:00
# 30               innsbruck-1964 1964-02-09 19:00:00 1964-01-29 07:00:00
# 31                    rome-1960 1960-09-11 19:00:00 1960-08-25 07:00:00
# 32            squaw-valley-1960 1960-02-28 04:00:00 1960-02-18 16:00:00
# 33               melbourne-1956 1956-12-08 10:00:00 1956-11-21 22:00:00
# 34       cortina-d-ampezzo-1956 1956-02-05 19:00:00 1956-01-26 07:00:00
# 35                helsinki-1952 1952-08-03 07:00:00 1952-07-19 07:00:00
# 36                    oslo-1952 1952-02-25 19:00:00 1952-02-14 07:00:00
# 37                  london-1948 1948-08-14 19:00:00 1948-07-29 07:00:00
# 38               st-moritz-1948 1948-02-08 19:00:00 1948-01-30 07:00:00
# 39                  berlin-1936 1936-08-16 19:00:00 1936-08-01 07:00:00
# 40  garmisch-partenkirchen-1936 1936-02-16 20:00:00 1936-02-06 08:00:00
# 41             los-angeles-1932 1932-08-14 19:00:00 1932-07-30 16:00:00
# 42             lake-placid-1932 1932-02-15 18:00:00 1932-02-04 13:00:00
# 43               amsterdam-1928 1928-08-12 19:00:00 1928-05-17 07:00:00
# 44               st-moritz-1928 1928-02-19 08:00:00 1928-02-11 08:00:00
# 45                   paris-1924 1924-07-27 19:00:00 1924-05-04 07:00:00
# 46                chamonix-1924 1924-02-05 20:00:00 1924-01-25 08:00:00
# 47                 antwerp-1920 1920-09-12 19:00:00 1920-04-20 07:00:00
# 48               stockholm-1912 1912-07-27 20:00:00 1912-05-05 08:00:00
# 49                  london-1908 1908-10-31 20:09:00 1908-04-27 08:00:00
# 50                st-louis-1904 1904-11-24 02:00:00 1904-07-01 14:00:00
# 51                   paris-1900 1900-10-28 19:50:39 1900-05-14 08:50:39
# 52                  athens-1896 1896-04-15 11:39:39 1896-04-06 11:38:39
#
#                        location                         name  season  year
# 0                         China                 Beijing 2022  Winter  2022
# 1                         Japan                   Tokyo 2020  Summer  2020
# 2             Republic of Korea             PyeongChang 2018  Winter  2018
# 3                        Brazil                     Rio 2016  Summer  2016
# 4            Russian Federation                   Sochi 2014  Winter  2014
# 5                 Great Britain                  London 2012  Summer  2012
# 6                        Canada               Vancouver 2010  Winter  2010
# 7                         China                 Beijing 2008  Summer  2008
# 8                         Italy                   Turin 2006  Winter  2006
# 9                        Greece                  Athens 2004  Summer  2004
# 10                United States          Salt Lake City 2002  Winter  2002
# 11                    Australia                  Sydney 2000  Summer  2000
# 12                        Japan                  Nagano 1998  Winter  1998
# 13                United States                 Atlanta 1996  Summer  1996
# 14                       Norway             Lillehammer 1994  Winter  1994
# 15                        Spain               Barcelona 1992  Summer  1992
# 16                       France             Albertville 1992  Winter  1992
# 17            Republic of Korea                   Seoul 1988  Summer  1988
# 18                       Canada                 Calgary 1988  Winter  1988
# 19                United States             Los Angeles 1984  Summer  1984
# 20                   Yugoslavia                Sarajevo 1984  Winter  1984
# 21                         USSR                  Moscow 1980  Summer  1980
# 22                United States             Lake Placid 1980  Winter  1980
# 23                       Canada                Montreal 1976  Summer  1976
# 24                      Austria               Innsbruck 1976  Winter  1976
# 25  Federal Republic of Germany                  Munich 1972  Summer  1972
# 26                        Japan                 Sapporo 1972  Winter  1972
# 27                       Mexico             Mexico City 1968  Summer  1968
# 28                       France                Grenoble 1968  Winter  1968
# 29                        Japan                   Tokyo 1964  Summer  1964
# 30                      Austria               Innsbruck 1964  Winter  1964
# 31                        Italy                    Rome 1960  Summer  1960
# 32                United States            Squaw Valley 1960  Winter  1960
# 33            Australia, Sweden               Melbourne 1956  Summer  1956
# 34                        Italy       Cortina d'Ampezzo 1956  Winter  1956
# 35                      Finland                Helsinki 1952  Summer  1952
# 36                       Norway                    Oslo 1952  Winter  1952
# 37                Great Britain                  London 1948  Summer  1948
# 38                  Switzerland              St. Moritz 1948  Winter  1948
# 39                      Germany                  Berlin 1936  Summer  1936
# 40                      Germany  Garmisch-Partenkirchen 1936  Winter  1936
# 41                United States             Los Angeles 1932  Summer  1932
# 42                United States             Lake Placid 1932  Winter  1932
# 43                  Netherlands               Amsterdam 1928  Summer  1928
# 44                  Switzerland              St. Moritz 1928  Winter  1928
# 45                       France                   Paris 1924  Summer  1924
# 46                       France                Chamonix 1924  Winter  1924
# 47                      Belgium                 Antwerp 1920  Summer  1920
# 48                       Sweden               Stockholm 1912  Summer  1912
# 49                Great Britain                  London 1908  Summer  1908
# 50                United States               St. Louis 1904  Summer  1904
# 51                       France                   Paris 1900  Summer  1900
# 52                       Greece                  Athens 1896  Summer  1896

# %%
olympic_hosts.columns = ["hostid", "enddate", "startdate","location","name","season","year"]

# %%
olympic_hosts.to_sql("olympichosts", con=engine, if_exists="append", index=False)
# Out:
# 53

# %%
life_expectancy = pd.read_csv("./life-expectancy.csv", header=0)

# %%
life_expectancy
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1950
# 1      Afghanistan  AFG  1951
# 2      Afghanistan  AFG  1952
# 3      Afghanistan  AFG  1953
# 4      Afghanistan  AFG  1954
# ...            ...  ...   ...
# 20750     Zimbabwe  ZWE  2017
# 20751     Zimbabwe  ZWE  2018
# 20752     Zimbabwe  ZWE  2019
# 20753     Zimbabwe  ZWE  2020
# 20754     Zimbabwe  ZWE  2021
#
#        Period life expectancy at birth - Sex: all - Age: 0
# 0                                                27.7275
# 1                                                27.9634
# 2                                                28.4456
# 3                                                28.9304
# 4                                                29.2258
# ...                                                  ...
# 20750                                            60.7095
# 20751                                            61.4141
# 20752                                            61.2925
# 20753                                            61.1242
# 20754                                            59.2531
#
# [20755 rows x 4 columns]

# %%
life_expectancy_cleaned = life_expectancy.dropna()

# %%
life_expectancy_cleaned
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1950
# 1      Afghanistan  AFG  1951
# 2      Afghanistan  AFG  1952
# 3      Afghanistan  AFG  1953
# 4      Afghanistan  AFG  1954
# ...            ...  ...   ...
# 20750     Zimbabwe  ZWE  2017
# 20751     Zimbabwe  ZWE  2018
# 20752     Zimbabwe  ZWE  2019
# 20753     Zimbabwe  ZWE  2020
# 20754     Zimbabwe  ZWE  2021
#
#        Period life expectancy at birth - Sex: all - Age: 0
# 0                                                27.7275
# 1                                                27.9634
# 2                                                28.4456
# 3                                                28.9304
# 4                                                29.2258
# ...                                                  ...
# 20750                                            60.7095
# 20751                                            61.4141
# 20752                                            61.2925
# 20753                                            61.1242
# 20754                                            59.2531
#
# [19061 rows x 4 columns]

# %%
cursor.execute("CREATE TABLE lifeexpectancy (country VARCHAR(255), code VARCHAR(255), year INT, lifeexpectancy FLOAT,PRIMARY KEY (code, year));")

# %%
connection.commit()

# %%
life_expectancy_cleaned.columns= ["country","code","year","lifeexpectancy"]

# %%
life_expectancy_cleaned["lifeexpectancy"] = pd.to_numeric(life_expectancy_cleaned["lifeexpectancy"])
# Out:
# /tmp/ipykernel_11128/1100360967.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   life_expectancy_cleaned["lifeexpectancy"] = pd.to_numeric(life_expectancy_cleaned["lifeexpectancy"])

# %%
life_expectancy_cleaned.dtypes
# Out:
# country            object
# code               object
# year                int64
# lifeexpectancy    float64
# dtype: object

# %%
life_expectancy_cleaned.to_sql("lifeexpectancy", con=engine, if_exists="append", index=False)
# Out:
# 61

# %%
olympic_medals = pd.read_csv("./olympic_medals.csv", header=0)

# %%
olympic_medals
# Out:
#       discipline_title     slug_game                      event_title  \
# 0              Curling  beijing-2022                    Mixed Doubles
# 1              Curling  beijing-2022                    Mixed Doubles
# 2              Curling  beijing-2022                    Mixed Doubles
# 3              Curling  beijing-2022                    Mixed Doubles
# 4              Curling  beijing-2022                    Mixed Doubles
# ...                ...           ...                              ...
# 21692    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting   athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type participant_title  \
# 0            Mixed       GOLD         GameTeam             Italy
# 1            Mixed       GOLD         GameTeam             Italy
# 2            Mixed     SILVER         GameTeam            Norway
# 3            Mixed     SILVER         GameTeam            Norway
# 4            Mixed     BRONZE         GameTeam            Sweden
# ...            ...        ...              ...               ...
# 21692          Men     SILVER          Athlete               NaN
# 21693          Men     BRONZE          Athlete               NaN
# 21694          Men       GOLD          Athlete               NaN
# 21695          Men     SILVER          Athlete               NaN
# 21696          Men     BRONZE          Athlete               NaN
#
#                                              athlete_url  \
# 0      https://olympics.com/en/athletes/stefania-cons...
# 1          https://olympics.com/en/athletes/amos-mosaner
# 2      https://olympics.com/en/athletes/kristin-skaslien
# 3      https://olympics.com/en/athletes/magnus-nedreg...
# 4         https://olympics.com/en/athletes/almida-de-val
# ...                                                  ...
# 21692      https://olympics.com/en/athletes/viggo-jensen
# 21693                                                NaN
# 21694      https://olympics.com/en/athletes/viggo-jensen
# 21695  https://olympics.com/en/athletes/launceston-el...
# 21696   https://olympics.com/en/athletes/sotirios-versis
#
#              athlete_full_name   country_name country_code  \
# 0         Stefania CONSTANTINI          Italy           IT
# 1                 Amos MOSANER          Italy           IT
# 2             Kristin SKASLIEN         Norway           NO
# 3           Magnus NEDREGOTTEN         Norway           NO
# 4                Almida DE VAL         Sweden           SE
# ...                        ...            ...          ...
# 21692             Viggo JENSEN        Denmark           DK
# 21693  Alexandros Nikolopoulos         Greece           GR
# 21694             Viggo JENSEN        Denmark           DK
# 21695        Launceston ELLIOT  Great Britain           GB
# 21696          Sotirios VERSIS         Greece           GR
#
#       country_3_letter_code
# 0                       ITA
# 1                       ITA
# 2                       NOR
# 3                       NOR
# 4                       SWE
# ...                     ...
# 21692                   DEN
# 21693                   GRE
# 21694                   DEN
# 21695                   GBR
# 21696                   GRE
#
# [21697 rows x 12 columns]

# %%
olympic_medals.dtypes
# Out:
# discipline          object
# hostid              object
# event               object
# gender              object
# medal               object
# participanttype     object
# participanttitle    object
# url                 object
# name                object
# country             object
# code                object
# code3               object
# dtype: object

# %%
olympic_medals.columns = ["discipline","hostid","event","gender","medal","participanttype","participanttitle","url","name","country","code","code3"]

# %%
cursor.execute("CREATE TABLE olympicmedals (discipline VARCHAR(255),hostid VARCHAR(255),event VARCHAR(255),gender VARCHAR(255),medal VARCHAR(255),participanttype VARCHAR(255),participanttitle VARCHAR(255),url VARCHAR(255),name VARCHAR(255),country VARCHAR(255),code VARCHAR(255),code3 VARCHAR(255));")

# %%
connection.commit()

# %%
olympic_medals.to_sql("olympicmedals", con=engine, if_exists="append", index=False)
# Out:
# 697

# %%
connection.rollback()

# %%
mental_illness = pd.read_csv("./mental-illness.csv",header=0)

# %%
mental_illness
# Out:
#           country code  year  depression  schizophrenia    bipolar  \
# 0     Afghanistan  AFG  1990   895.22565     138.248250  147.64412
# 1     Afghanistan  AFG  1991   893.88434     137.761220  147.56696
# 2     Afghanistan  AFG  1992   892.34973     137.080300  147.13086
# 3     Afghanistan  AFG  1993   891.51587     136.486020  146.78812
# 4     Afghanistan  AFG  1994   891.39160     136.183230  146.58481
# ...           ...  ...   ...         ...            ...        ...
# 6835     Zimbabwe  ZWE  2015   546.46204     127.108720  115.32073
# 6836     Zimbabwe  ZWE  2016   547.27765     127.142105  114.98700
# 6837     Zimbabwe  ZWE  2017   547.62270     127.465050  115.32798
# 6838     Zimbabwe  ZWE  2018   546.57184     127.681210  115.42796
# 6839     Zimbabwe  ZWE  2019   544.53160     128.216030  115.38145
#
#       eatingdisorder    anxiety
# 0          26.471115  440.33000
# 1          25.548681  439.47202
# 2          24.637949  437.60718
# 3          23.863169  436.69104
# 4          23.189074  436.76800
# ...              ...        ...
# 6835       20.423056  302.20868
# 6836       20.647228  302.68216
# 6837       20.791725  302.88626
# 6838       20.916480  301.58250
# 6839       21.011127  298.20325
#
# [6840 rows x 8 columns]

# %%
mental_illness.columns = ["country","code","year","depression","schizophrenia","bipolar","eatingdisorder","anxiety"]

# %%
mental_illness.dtypes
# Out:
# country            object
# code               object
# year                int64
# depression        float64
# schizophrenia     float64
# bipolar           float64
# eatingdisorder    float64
# anxiety           float64
# dtype: object

# %%
cursor.execute("CREATE TABLE mentalillness (country VARCHAR(255),code VARCHAR(255),year INT,depression FLOAT,schizophrenia FLOAT,bipolar FLOAT,eatingdisorder FLOAT,anxiety FLOAT,PRIMARY KEY (code, year));")

# %%
mental_illness=mental_illness.dropna()

# %%
connection.commit()

# %%
mental_illness.to_sql("mentalillness", con=engine, if_exists="append", index=False)
# Out:
# 150

# %%
economic_data = pd.read_csv("./Economic data.csv",header=0)

# %%
economic_data
# Out:
#      year yearCode                country code poverty       gdpCap  \
# 0    2020   YR2020            Afghanistan  AFG     NaN  516.8667974
# 1    2020   YR2020                Albania  ALB       0  5343.037704
# 2    2020   YR2020                Algeria  DZA     NaN  3354.157303
# 3    2020   YR2020                Andorra  AND     NaN    37207.222
# 4    2020   YR2020                 Angola  AGO     NaN  1502.950754
# ..    ...      ...                    ...  ...     ...          ...
# 195  2020   YR2020               Viet Nam  VNM     0.7  3586.347297
# 196  2020   YR2020  Virgin Islands (U.S.)  VIR     NaN   39552.1686
# 197  2020   YR2020            Yemen, Rep.  YEM     NaN  583.8756629
# 198  2020   YR2020                 Zambia  ZMB     NaN  956.8317475
# 199  2020   YR2020               Zimbabwe  ZWE     NaN  1372.696674
#
#         gdpGrowth       intSrv  mort      hlthExp   govHlthCap   prvHlthCap  \
# 0    -5.364665931  34.94796166  44.8  15.53361392    6.1311352  61.20481468
# 1    -2.745238678  884.8250911   8.4           ..  154.8976524           ..
# 2    -6.729941651  48.46764679  19.6   6.32117987  134.4669044  80.29914715
# 3    -12.73507756  9665.379665   2.7   9.05175877  2441.683051   895.234785
# 4    -8.672432129   19.7436402  48.7   2.91183472  21.34275969  27.28717169
# ..            ...          ...   ...          ...          ...          ...
# 195   1.937355342  3127.957716  16.6   4.68066788  74.99471991   89.8672161
# 196  -1.798090794  649.1673723    ..           ..           ..           ..
# 197            ..  5.234783769  45.8           ..           ..           ..
# 198   -5.59573306  39.36027143  41.1   5.61788416  23.36391858   7.74727054
# 199  -9.670404777  70.64604951  36.6   3.42558146  11.19550347  11.26707487
#
#       extHlthCap
# 0    12.95210116
# 1             ..
# 2     0.08572689
# 3             ..
# 4     2.11269093
# ..           ...
# 195   1.36990087
# 196           ..
# 197           ..
# 198  22.64247137
# 199  28.21393346
#
# [200 rows x 13 columns]

# %%
economic_data.columns = ["year", "yearcode", "country", "code", "poverty", "gdpcap", "gdpgrowth", "intsrv","mort", "hlthexp", "govhlthcap", "prvhlthcap", "exthlthcap"]

# %%
null_values_summary = economic_data.isnull().sum()
null_values_summary
# Out:
# year          0
# yearCode      0
# country       0
# code          0
# poverty       0
# gdpCap        0
# gdpGrowth     0
# intSrv        0
# mort          0
# hlthExp       0
# govHlthCap    0
# prvHlthCap    0
# extHlthCap    0
# dtype: int64

# %%
economic_data["poverty"] = pd.to_numeric(economic_data["poverty"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string ".."
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 economic_data["poverty"] = pd.to_numeric(economic_data["poverty"])
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/tools/numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
#     221         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     222         or isinstance(values_dtype, StringDtype),
#     223     )
#     224 except (ValueError, TypeError):
#     225     if errors == "raise":
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2322, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string ".." at position 0

# %%
import numpy as np

# %%
economic_data['extHlthCap'] = economic_data['extHlthCap'].replace('..', np.nan)
# Out:
# /tmp/ipykernel_11128/735914748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['extHlthCap'] = economic_data['extHlthCap'].replace('..', np.nan)

# %%
economic_data["poverty"]= pd.to_numeric(economic_data["poverty"])
# Out:
# /tmp/ipykernel_11128/846855046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data["poverty"]= pd.to_numeric(economic_data["poverty"])

# %%
economic_data
# Out:
#      year yearcode                country code  poverty       gdpcap  \
# 0    2020   YR2020            Afghanistan  AFG      NaN  516.8667974
# 1    2020   YR2020                Albania  ALB      0.0  5343.037704
# 2    2020   YR2020                Algeria  DZA      NaN  3354.157303
# 3    2020   YR2020                Andorra  AND      NaN    37207.222
# 4    2020   YR2020                 Angola  AGO      NaN  1502.950754
# ..    ...      ...                    ...  ...      ...          ...
# 195  2020   YR2020               Viet Nam  VNM      0.7  3586.347297
# 196  2020   YR2020  Virgin Islands (U.S.)  VIR      NaN   39552.1686
# 197  2020   YR2020            Yemen, Rep.  YEM      NaN  583.8756629
# 198  2020   YR2020                 Zambia  ZMB      NaN  956.8317475
# 199  2020   YR2020               Zimbabwe  ZWE      NaN  1372.696674
#
#         gdpgrowth       intsrv  mort      hlthexp   govhlthcap   prvhlthcap  \
# 0    -5.364665931  34.94796166  44.8  15.53361392    6.1311352  61.20481468
# 1    -2.745238678  884.8250911   8.4          NaN  154.8976524          NaN
# 2    -6.729941651  48.46764679  19.6   6.32117987  134.4669044  80.29914715
# 3    -12.73507756  9665.379665   2.7   9.05175877  2441.683051   895.234785
# 4    -8.672432129   19.7436402  48.7   2.91183472  21.34275969  27.28717169
# ..            ...          ...   ...          ...          ...          ...
# 195   1.937355342  3127.957716  16.6   4.68066788  74.99471991   89.8672161
# 196  -1.798090794  649.1673723   NaN          NaN          NaN          NaN
# 197           NaN  5.234783769  45.8          NaN          NaN          NaN
# 198   -5.59573306  39.36027143  41.1   5.61788416  23.36391858   7.74727054
# 199  -9.670404777  70.64604951  36.6   3.42558146  11.19550347  11.26707487
#
#       exthlthcap
# 0    12.95210116
# 1            NaN
# 2     0.08572689
# 3            NaN
# 4     2.11269093
# ..           ...
# 195   1.36990087
# 196          NaN
# 197          NaN
# 198  22.64247137
# 199  28.21393346
#
# [200 rows x 13 columns]

# %%
cursor.execute("CREATE TABLE economicdata (year INT,yearcode VARCHAR(255),country VARCHAR(255),code VARCHAR(255),poverty FLOAT,gdpcap FLOAT,gdpgrowth FLOAT,intsrv FLOAT,mort FLOAT,hlthexp FLOAT,govhlthcap FLOAT,prvhlthcap FLOAT,exthlthCap FLOAT, PRIMARY KEY(code,year));")

# %%
connection.rollback()

# %%
connection.commit()

# %%
economic_data.to_sql("economicdata", con=engine, if_exists="append", index=False)
# Out:
# 200

# %%
global_population = pd.read_csv("./Global Population.csv",header=0,encoding='ISO-8859-1')

# %%
import chardet

# Detect encoding of the CSV file
with open('./Global Population.csv', 'rb') as f:
    result = chardet.detect(f.read())
    encoding = result['encoding']

print(f"Detected encoding: {encoding}")
# Out:
# Detected encoding: ISO-8859-1

# %%
global_population = global_population[:-1]

# %%
# Out:
#     Population (Millions of people)      1980      1981      1982      1983  \
# 1                       Afghanistan   no data   no data   no data   no data
# 2                           Albania     2.672     2.726     2.784     2.844
# 3                           Algeria    18.666    19.246    19.864    20.516
# 4                           Andorra   no data   no data   no data   no data
# 5                            Angola     8.272     8.495      8.72     8.948
# ..                              ...       ...       ...       ...       ...
# 224   Major advanced economies (G7)   612.155   616.177   619.745   623.047
# 225    Middle East and Central Asia   254.673    262.85   271.095   279.549
# 226        Other advanced economies    112.56   114.089   115.636   117.012
# 227              Sub-Saharan Africa   342.745   352.398   362.565   373.099
# 228                           World  4009.286  4082.448  4157.684  4231.389
#
#          1984      1985      1986      1987      1988  ...      2019  \
# 1     no data   no data   no data   no data   no data  ...      32.2
# 2       2.904     2.965     3.023     3.084     3.142  ...     2.881
# 3      21.175      22.2      22.8      23.4      24.1  ...    43.424
# 4     no data   no data   no data   no data   no data  ...     0.078
# 5       9.185     10.35    10.646    10.918    11.214  ...    32.354
# ..        ...       ...       ...       ...       ...  ...       ...
# 224   626.158   629.495   633.018   636.492   640.455  ...   767.111
# 225   288.557    297.65   306.682   314.912   323.543  ...   822.958
# 226   118.267   119.403    120.51   121.721   123.038  ...   173.316
# 227   384.021   395.902   407.207   418.858   430.534  ...  1026.814
# 228  4306.121  4383.428  4462.501  4542.998  4623.714  ...  7593.398
#
#          2020      2021      2022      2023      2024      2025      2026  \
# 1      32.941    33.698    34.263   no data   no data   no data   no data
# 2       2.878     2.873     2.866     2.858      2.85      2.84     2.831
# 3      43.851    44.577    45.291    45.973    46.626    47.251    47.851
# 4       0.078      0.08     0.082     0.084     0.086     0.088      0.09
# 5      33.428    34.504    35.711    36.783    37.886    39.023    40.194
# ..        ...       ...       ...       ...       ...       ...       ...
# 224   770.236   771.188   773.813   776.204   778.064   779.836   781.511
# 225   838.452   852.037   867.872     848.6   863.738   879.116    894.74
# 226   173.729   173.571   174.874   175.992   176.883   177.651   178.412
# 227  1054.129  1081.266  1108.902  1137.025  1165.892  1195.365  1225.766
# 228  7669.821  7738.554  7799.478  7836.053  7910.277  7984.971  8059.267
#
#          2027      2028
# 1     no data   no data
# 2       2.821      2.81
# 3      48.428    48.983
# 4       0.093     0.095
# 5      41.399    42.641
# ..        ...       ...
# 224   783.115   784.666
# 225   910.628   926.964
# 226   179.175    179.94
# 227  1257.372  1289.432
# 228  8134.704  8209.644
#
# [228 rows x 50 columns]

# %%
global_population_melted = pd.melt(global_population, id_vars=["Population (Millions of people)"], var_name="Year", value_name="Population")

# %%
global_population_melted
# Out:
#       Population (Millions of people)  Year Population
# 0                         Afghanistan  1980    no data
# 1                             Albania  1980      2.672
# 2                             Algeria  1980     18.666
# 3                             Andorra  1980    no data
# 4                              Angola  1980      8.272
# ...                               ...   ...        ...
# 11167   Major advanced economies (G7)  2028    784.666
# 11168    Middle East and Central Asia  2028    926.964
# 11169        Other advanced economies  2028     179.94
# 11170              Sub-Saharan Africa  2028   1289.432
# 11171                           World  2028   8209.644
#
# [11172 rows x 3 columns]

# %%
global_population_melted.dtypes
# Out:
# Population (Millions of people)    object
# Year                               object
# Population                         object
# dtype: object

# %%
global_population_melted['Population'] = global_population_melted['Population'].replace('no data', np.nan)

# %%
global_population_melted
# Out:
#       Population (Millions of people)  Year Population
# 0                         Afghanistan  1980        NaN
# 1                             Albania  1980      2.672
# 2                             Algeria  1980     18.666
# 3                             Andorra  1980        NaN
# 4                              Angola  1980      8.272
# ...                               ...   ...        ...
# 11167   Major advanced economies (G7)  2028    784.666
# 11168    Middle East and Central Asia  2028    926.964
# 11169        Other advanced economies  2028     179.94
# 11170              Sub-Saharan Africa  2028   1289.432
# 11171                           World  2028   8209.644
#
# [11172 rows x 3 columns]

# %%
cursor.execute("CREATE TABLE population (country VARCHAR(255), year INT, population FLOAT,PRIMARY KEY (country, year));")

# %%
connection.commit()

# %%
global_population_melted.columns = ["country","year","population"]

# %%
global_population_melted.to_sql("population", con=engine, if_exists="append", index=False)
# Out:
# 172

# %%
cursor.execute("ALTER TABLE olympicmedals DROP COLUMN discipline, DROP COLUMN hostid;")

# %%
connection.commit()

# %%
cursor.execute("ALTER TABLE olympicmedals DROP COLUMN event, DROP COLUMN gender, DROP COLUMN participanttype;")

# %%
connection.commit()

# %%
cursor.execute("ALTER TABLE olympicmedals DROP COLUMN participanttitle, DROP COLUMN url, DROP COLUMN name;")

# %%
connection.commit()

# %%
cursor.execute("ALTER TABLE olympicmedals ADD COLUMN id SERIAL;")

# %%
connection.commit()

# %%
cursor.execute("ALTER TABLE olympicmedals ADD PRIMARY KEY (id);")

# %%
connection.commit()

# %%
cursor.execute("ALTER TABLE countries ALTER country SET NOT NULL")

# %%
connection.commit()

# %%
cursor.execute("ALTER TABLE countries ALTER continent SET NOT NULL")

# %%
cursor.execute("ALTER TABLE economicdata ALTER year SET NOT NULL")

# %%
connection.commit()

# %%
cursor.execute("ALTER TABLE economicdata ALTER yearcode SET NOT NULL")

# %%
cursor.execute("ALTER TABLE economicdata ALTER country SET NOT NULL")

# %%
cursor.execute("ALTER TABLE economicdata ALTER code SET NOT NULL")

# %%
connection.commit()

# %%
cursor.execute("ROLLBACK;")

# %%
cursor.execute("ALTER TABLE lifeexpectancy ALTER country SET NOT NULL,ALTER code SET NOT NULL,ALTER year SET NOT NULL,ALTER lifeexpectancy SET NOT NULL;")

# %%
connection.commit()

# %%
cursor.execute("ALTER TABLE mentalillness ALTER country SET NOT NULL,ALTER code SET NOT NULL,ALTER year SET NOT NULL;")

# %%
cursor.execute("ALTER TABLE olympicmedals ALTER medal SET NOT NULL,ALTER country SET NOT NULL,ALTER code3 SET NOT NULL;")

# %%
cursor.execute("ALTER TABLE olympicmedals DROP COLUMN code;")

# %%
cursor.execute("ALTER TABLE olympicmedals RENAME COLUMN code3 TO code;")

# %%
cursor.execute("ALTER TABLE olympichosts DROP CONSTRAINT olympichosts_pkey;")

# %%
cursor.execute("ALTER TABLE olympichosts ADD CONSTRAINT olympichosts_pkey PRIMARY KEY (hostid);")

# %%
cursor.execute("ALTER TABLE olympichosts ALTER location SET NOT NULL,ALTER year SET NOT NULL,ALTER season SET NOT NULL;")

# %%
cursor.execute("ALTER TABLE olympichosts DROP COLUMN name;")

# %%
cursor.execute("CREATE TABLE factolympicmental ( year INT, code VARCHAR(255),country VARCHAR(255), anxietystat FLOAT, depressionstat FLOAT,medals INT);")

# %%
connection.commit()

# %%
factolympicdata = []
factolympiccolumns =  ["year","code","country","medalid"]

# %%
factdf = pd.DataFrame(factolympicdata,columns=factolympiccolumns)

# %%
factdf
# Out:
# Empty DataFrame
# Columns: [year, code, country, medalid]
# Index: []

# %%
medals_aggregated = medals.groupby(['country']).size().reset_index(name='TotalMedals')

# %%
medals_aggregated
# Out:
#                     country  TotalMedals
# 0               Afghanistan            2
# 1                   Algeria           17
# 2                 Argentina           87
# 3                   Armenia           18
# 4               Australasia           12
# ..                      ...          ...
# 149      Virgin Islands, US            1
# 150  West Indies Federation            2
# 151              Yugoslavia           94
# 152                  Zambia            2
# 153                Zimbabwe            8
#
# [154 rows x 2 columns]

# %%
medal_types = medals.groupby(['medal','country']).size().reset_index(name='TotalMedals')

# %%
medal_types
# Out:
#       medal             country  TotalMedals
# 0    BRONZE         Afghanistan            2
# 1    BRONZE             Algeria            8
# 2    BRONZE           Argentina           37
# 3    BRONZE             Armenia            8
# 4    BRONZE         Australasia            5
# ..      ...                 ...          ...
# 376  SILVER             Vietnam            3
# 377  SILVER  Virgin Islands, US            1
# 378  SILVER          Yugoslavia           35
# 379  SILVER              Zambia            1
# 380  SILVER            Zimbabwe            4
#
# [381 rows x 3 columns]

# %%
olympic_medals
# Out:
#           discipline        hostid                            event gender  \
# 0            Curling  beijing-2022                    Mixed Doubles  Mixed
# 1            Curling  beijing-2022                    Mixed Doubles  Mixed
# 2            Curling  beijing-2022                    Mixed Doubles  Mixed
# 3            Curling  beijing-2022                    Mixed Doubles  Mixed
# 4            Curling  beijing-2022                    Mixed Doubles  Mixed
# ...              ...           ...                              ...    ...
# 21692  Weightlifting   athens-1896  heavyweight - one hand lift men    Men
# 21693  Weightlifting   athens-1896  heavyweight - one hand lift men    Men
# 21694  Weightlifting   athens-1896  heavyweight - two hand lift men    Men
# 21695  Weightlifting   athens-1896  heavyweight - two hand lift men    Men
# 21696  Weightlifting   athens-1896  heavyweight - two hand lift men    Men
#
#         medal participanttype participanttitle  \
# 0        GOLD        GameTeam            Italy
# 1        GOLD        GameTeam            Italy
# 2      SILVER        GameTeam           Norway
# 3      SILVER        GameTeam           Norway
# 4      BRONZE        GameTeam           Sweden
# ...       ...             ...              ...
# 21692  SILVER         Athlete              NaN
# 21693  BRONZE         Athlete              NaN
# 21694    GOLD         Athlete              NaN
# 21695  SILVER         Athlete              NaN
# 21696  BRONZE         Athlete              NaN
#
#                                                      url  \
# 0      https://olympics.com/en/athletes/stefania-cons...
# 1          https://olympics.com/en/athletes/amos-mosaner
# 2      https://olympics.com/en/athletes/kristin-skaslien
# 3      https://olympics.com/en/athletes/magnus-nedreg...
# 4         https://olympics.com/en/athletes/almida-de-val
# ...                                                  ...
# 21692      https://olympics.com/en/athletes/viggo-jensen
# 21693                                                NaN
# 21694      https://olympics.com/en/athletes/viggo-jensen
# 21695  https://olympics.com/en/athletes/launceston-el...
# 21696   https://olympics.com/en/athletes/sotirios-versis
#
#                           name        country code code3
# 0         Stefania CONSTANTINI          Italy   IT   ITA
# 1                 Amos MOSANER          Italy   IT   ITA
# 2             Kristin SKASLIEN         Norway   NO   NOR
# 3           Magnus NEDREGOTTEN         Norway   NO   NOR
# 4                Almida DE VAL         Sweden   SE   SWE
# ...                        ...            ...  ...   ...
# 21692             Viggo JENSEN        Denmark   DK   DEN
# 21693  Alexandros Nikolopoulos         Greece   GR   GRE
# 21694             Viggo JENSEN        Denmark   DK   DEN
# 21695        Launceston ELLIOT  Great Britain   GB   GBR
# 21696          Sotirios VERSIS         Greece   GR   GRE
#
# [21697 rows x 12 columns]

# %%
import re

# %%
 year_pattern = r'\b(18|19|20)\d{2}\b'

# %%
def extract_year(value):
    year_pattern = r'\b(18|19|20)\d{2}\b'
    match = re.search(year_pattern, value)
    if match:
        return int(match.group(0))  # Convert the matched year to an integer
    else:
        return None

# %%
olympic_medals['hostid'] = olympic_medals['hostid'].apply(extract_year)

# %%
medalsolympic_medals
# Out:
#           discipline  hostid                            event gender   medal  \
# 0            Curling    2022                    Mixed Doubles  Mixed    GOLD
# 1            Curling    2022                    Mixed Doubles  Mixed    GOLD
# 2            Curling    2022                    Mixed Doubles  Mixed  SILVER
# 3            Curling    2022                    Mixed Doubles  Mixed  SILVER
# 4            Curling    2022                    Mixed Doubles  Mixed  BRONZE
# ...              ...     ...                              ...    ...     ...
# 21692  Weightlifting    1896  heavyweight - one hand lift men    Men  SILVER
# 21693  Weightlifting    1896  heavyweight - one hand lift men    Men  BRONZE
# 21694  Weightlifting    1896  heavyweight - two hand lift men    Men    GOLD
# 21695  Weightlifting    1896  heavyweight - two hand lift men    Men  SILVER
# 21696  Weightlifting    1896  heavyweight - two hand lift men    Men  BRONZE
#
#       participanttype participanttitle  \
# 0            GameTeam            Italy
# 1            GameTeam            Italy
# 2            GameTeam           Norway
# 3            GameTeam           Norway
# 4            GameTeam           Sweden
# ...               ...              ...
# 21692         Athlete              NaN
# 21693         Athlete              NaN
# 21694         Athlete              NaN
# 21695         Athlete              NaN
# 21696         Athlete              NaN
#
#                                                      url  \
# 0      https://olympics.com/en/athletes/stefania-cons...
# 1          https://olympics.com/en/athletes/amos-mosaner
# 2      https://olympics.com/en/athletes/kristin-skaslien
# 3      https://olympics.com/en/athletes/magnus-nedreg...
# 4         https://olympics.com/en/athletes/almida-de-val
# ...                                                  ...
# 21692      https://olympics.com/en/athletes/viggo-jensen
# 21693                                                NaN
# 21694      https://olympics.com/en/athletes/viggo-jensen
# 21695  https://olympics.com/en/athletes/launceston-el...
# 21696   https://olympics.com/en/athletes/sotirios-versis
#
#                           name        country code code3
# 0         Stefania CONSTANTINI          Italy   IT   ITA
# 1                 Amos MOSANER          Italy   IT   ITA
# 2             Kristin SKASLIEN         Norway   NO   NOR
# 3           Magnus NEDREGOTTEN         Norway   NO   NOR
# 4                Almida DE VAL         Sweden   SE   SWE
# ...                        ...            ...  ...   ...
# 21692             Viggo JENSEN        Denmark   DK   DEN
# 21693  Alexandros Nikolopoulos         Greece   GR   GRE
# 21694             Viggo JENSEN        Denmark   DK   DEN
# 21695        Launceston ELLIOT  Great Britain   GB   GBR
# 21696          Sotirios VERSIS         Greece   GR   GRE
#
# [21697 rows x 12 columns]

# %%
medals.insert(0,"Year",olympic_medals["hostid"],True)

# %%
mental_illness
# Out:
#           country code  year  depression  schizophrenia    bipolar  \
# 0     Afghanistan  AFG  1990   895.22565     138.248250  147.64412
# 1     Afghanistan  AFG  1991   893.88434     137.761220  147.56696
# 2     Afghanistan  AFG  1992   892.34973     137.080300  147.13086
# 3     Afghanistan  AFG  1993   891.51587     136.486020  146.78812
# 4     Afghanistan  AFG  1994   891.39160     136.183230  146.58481
# ...           ...  ...   ...         ...            ...        ...
# 6835     Zimbabwe  ZWE  2015   546.46204     127.108720  115.32073
# 6836     Zimbabwe  ZWE  2016   547.27765     127.142105  114.98700
# 6837     Zimbabwe  ZWE  2017   547.62270     127.465050  115.32798
# 6838     Zimbabwe  ZWE  2018   546.57184     127.681210  115.42796
# 6839     Zimbabwe  ZWE  2019   544.53160     128.216030  115.38145
#
#       eatingdisorder    anxiety
# 0          26.471115  440.33000
# 1          25.548681  439.47202
# 2          24.637949  437.60718
# 3          23.863169  436.69104
# 4          23.189074  436.76800
# ...              ...        ...
# 6835       20.423056  302.20868
# 6836       20.647228  302.68216
# 6837       20.791725  302.88626
# 6838       20.916480  301.58250
# 6839       21.011127  298.20325
#
# [6840 rows x 8 columns]

# %%
medals
# Out:
#        year   medal        country code     id
# 0      2022    GOLD          Italy  ITA      1
# 1      2022    GOLD          Italy  ITA      2
# 2      2022  SILVER         Norway  NOR      3
# 3      2022  SILVER         Norway  NOR      4
# 4      2022  BRONZE         Sweden  SWE      5
# ...     ...     ...            ...  ...    ...
# 21692  1896  SILVER        Denmark  DEN  21693
# 21693  1896  BRONZE         Greece  GRE  21694
# 21694  1896    GOLD        Denmark  DEN  21695
# 21695  1896  SILVER  Great Britain  GBR  21696
# 21696  1896  BRONZE         Greece  GRE  21697
#
# [21697 rows x 5 columns]

# %%
countrydf
# Out:
#               country      continent
# 0             country         region
# 1               India           Asia
# 2               China           Asia
# 3       United States  North America
# 4           Indonesia           Asia
# ..                ...            ...
# 230        Montserrat  North America
# 231  Falkland Islands  South America
# 232              Niue        Oceania
# 233           Tokelau        Oceania
# 234      Vatican City         Europe
#
# [235 rows x 2 columns]

# %%
cursor.execute("ROLLBACK")

# %%
cursor.execute("CREATE TABLE medalsnew ( year int, medal VARCHAR(255), country VARCHAR(255),code VARCHAR (255), id INT PRIMARY KEY);")

# %%
connection.commit()

# %%
medals.to_sql("medalsnew", con=engine, if_exists="append", index=False)
# Out:
# 697

# %%
facttabletest = pd.DataFrame(factolympicdata,columns=factolympiccolumns)

# %%
facttabletest
# Out:
# Empty DataFrame
# Columns: [year, code, country, medalid]
# Index: []

# %%
facttabletest

# %%
test = pd.merge(medals, mental_illness, on=['year', 'code','country'], how='inner')

# %%
test
# Out:
#       year   medal     country code     id  depression  schizophrenia  \
# 0     2018    GOLD      Norway  NOR   1544   560.33820      180.55357
# 1     2018    GOLD      Norway  NOR   1545   560.33820      180.55357
# 2     2018  BRONZE      Norway  NOR   1558   560.33820      180.55357
# 3     2018    GOLD      Norway  NOR   1562   560.33820      180.55357
# 4     2018    GOLD      Norway  NOR   1568   560.33820      180.55357
# ...    ...     ...         ...  ...    ...         ...            ...
# 4215  1992  BRONZE    Suriname  SUR  10296   829.23750      173.13023
# 4216  1992  BRONZE   Argentina  ARG  10380   458.25125      199.43263
# 4217  1992  BRONZE   Argentina  ARG  10381   458.25125      199.43263
# 4218  1992  SILVER  Luxembourg  LUX  10518   664.50543      177.03981
# 4219  1992  SILVER  Luxembourg  LUX  10525   664.50543      177.03981
#
#         bipolar  eatingdisorder    anxiety
# 0     178.11180      100.930960  644.23810
# 1     178.11180      100.930960  644.23810
# 2     178.11180      100.930960  644.23810
# 3     178.11180      100.930960  644.23810
# 4     178.11180      100.930960  644.23810
# ...         ...             ...        ...
# 4215  193.65190       40.801826  390.63160
# 4216  211.82477       61.260650  485.97446
# 4217  211.82477       61.260650  485.97446
# 4218  192.51715       97.331680  508.95790
# 4219  192.51715       97.331680  508.95790
#
# [4220 rows x 10 columns]

# %%
test1 = pd.merge(test,countrydf,on=['country'],how="inner")

# %%
test1
# Out:
#       year   medal     country code     id  depression  schizophrenia  \
# 0     2018    GOLD      Norway  NOR   1544   560.33820      180.55357
# 1     2018    GOLD      Norway  NOR   1545   560.33820      180.55357
# 2     2018  BRONZE      Norway  NOR   1558   560.33820      180.55357
# 3     2018    GOLD      Norway  NOR   1562   560.33820      180.55357
# 4     2018    GOLD      Norway  NOR   1568   560.33820      180.55357
# ...    ...     ...         ...  ...    ...         ...            ...
# 4215  1992  BRONZE       Ghana  GHA  10154   751.65350      135.00745
# 4216  1992  SILVER        Peru  PER  10177   396.24810      175.47664
# 4217  1992  BRONZE    Suriname  SUR  10296   829.23750      173.13023
# 4218  1992  SILVER  Luxembourg  LUX  10518   664.50543      177.03981
# 4219  1992  SILVER  Luxembourg  LUX  10525   664.50543      177.03981
#
#         bipolar  eatingdisorder   anxiety      continent
# 0     178.11180      100.930960  644.2381         Europe
# 1     178.11180      100.930960  644.2381         Europe
# 2     178.11180      100.930960  644.2381         Europe
# 3     178.11180      100.930960  644.2381         Europe
# 4     178.11180      100.930960  644.2381         Europe
# ...         ...             ...       ...            ...
# 4215  117.25983       19.932873  283.0296         Africa
# 4216  199.75580       52.334090  521.2572  South America
# 4217  193.65190       40.801826  390.6316  South America
# 4218  192.51715       97.331680  508.9579         Europe
# 4219  192.51715       97.331680  508.9579         Europe
#
# [4220 rows x 11 columns]

# %%
cursor.execute("CREATE TABLE facttest (year INT,	medal VARCHAR,	country VARCHAR,	code VARCHAR,	id INT PRIMARY KEY	,depression FLOAT,	schizophrenia FLOAT,	bipolar FLOAT,	eatingdisorder FLOAT,	anxiety FLOAT,	continent VARCHAR);")

# %%
connection.commit()

# %%
test1.to_sql("facttest", con=engine, if_exists="append", index=False)
# Out:
# 220
